# %% [markdown]
# <a href="https://colab.research.google.com/github/SIININ/machine-learning/blob/main/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import numpy as np 
import pandas as pd

# %%
#1Relaod the dataset
dataset = pd.read_csv("https://gist.githubusercontent.com/kevin336/acbb2271e66c10a5b73aacf82ca82784/raw/e38afe62e088394d61ed30884dd50a6826eee0a8/employees.csv")
dataset.head(15)
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
# 5           203      Susan     Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204    Hermann       Baer     HBAER  515.123.8888  07-JUN-02
# 7           205    Shelley    Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206    William      Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100     Steven       King     SKING  515.123.4567  17-JUN-03
# 10          101      Neena    Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# 11          102        Lex    De Haan   LDEHAAN  515.123.4569  13-JAN-01
# ...

# %%
#2 dimension : rows, columns
dataset.shape
# Out:
# (50, 11)

# %%
dataset.describe()
# Out:
#        EMPLOYEE_ID        SALARY  DEPARTMENT_ID
# count    50.000000     50.000000       50.00000
# mean    134.760000   6182.320000       57.60000
# std      33.631594   4586.181772       25.11687
# min     100.000000   2100.000000       10.00000
# 25%     112.250000   2725.000000       50.00000
# 50%     124.500000   4600.000000       50.00000
# 75%     136.750000   8150.000000       60.00000
# max     206.000000  24000.000000      110.00000

# %%
#3, check the variable(numerical/ categorical)
numerical_variable = dataset.columns[dataset.dtypes != 'object']
dataset[numerical_variabel].head(5)
# Out:
#    EMPLOYEE_ID  SALARY  DEPARTMENT_ID
# 0          198    2600             50
# 1          199    2600             50
# 2          200    4400             10
# 3          201   13000             20
# 4          202    6000             20

# %%
#Check categorical data
categorical_variable = dataset.columns[dataset.dtypes == 'object']
dataset[categorical_variable].head(5)
# Out:
#   FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE    JOB_ID  \
# 0     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07  SH_CLERK
# 1    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08  SH_CLERK
# 2   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03   AD_ASST
# 3    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04    MK_MAN
# 4        Pat        Fay      PFAY  603.123.6666  17-AUG-05    MK_REP
#
#   COMMISSION_PCT MANAGER_ID
# 0             -         124
# 1             -         124
# 2             -         101
# 3             -         100
# 4             -         201

# %%
#4. Identity the missing value
dataset.isnull()
# Out:
#     EMPLOYEE_ID  FIRST_NAME  LAST_NAME  EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0         False       False      False  False         False      False
# 1         False       False      False  False         False      False
# 2         False       False      False  False         False      False
# 3         False       False      False  False         False      False
# 4         False       False      False  False         False      False
# 5         False       False      False  False         False      False
# 6         False       False      False  False         False      False
# 7         False       False      False  False         False      False
# 8         False       False      False  False         False      False
# 9         False       False      False  False         False      False
# 10        False       False      False  False         False      False
# 11        False       False      False  False         False      False
# ...

# %%
#numerical_value
dataset[numerical_variable].isnull().head(5)
# Out:
#    EMPLOYEE_ID  SALARY  DEPARTMENT_ID
# 0        False   False          False
# 1        False   False          False
# 2        False   False          False
# 3        False   False          False
# 4        False   False          False

# %%
#categorical_value
dataset[categorical_variable].isnull().head(10)
# Out:
#    FIRST_NAME  LAST_NAME  EMAIL  PHONE_NUMBER  HIRE_DATE  JOB_ID  \
# 0       False      False  False         False      False   False
# 1       False      False  False         False      False   False
# 2       False      False  False         False      False   False
# 3       False      False  False         False      False   False
# 4       False      False  False         False      False   False
# 5       False      False  False         False      False   False
# 6       False      False  False         False      False   False
# 7       False      False  False         False      False   False
# 8       False      False  False         False      False   False
# 9       False      False  False         False      False   False
#
#    COMMISSION_PCT  MANAGER_ID
# 0           False       False
# 1           False       False
# 2           False       False
# 3           False       False
# 4           False       False
# 5           False       False
# 6           False       False
# ...

# %%
#5 find out the percentage at the missing values
len(dataset)
# Out:
# 50

# %%
dataset.isnull().sum()/len(dataset)
# Out:
# EMPLOYEE_ID       0.0
# FIRST_NAME        0.0
# LAST_NAME         0.0
# EMAIL             0.0
# PHONE_NUMBER      0.0
# HIRE_DATE         0.0
# JOB_ID            0.0
# SALARY            0.0
# COMMISSION_PCT    0.0
# MANAGER_ID        0.0
# DEPARTMENT_ID     0.0
# dtype: float64

# %%
#6 replace
dataset.fillna("sinin")
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %%
#7. Fill up the missing value with specific variable
dataset['SALARY'].replace("REVENUE", "INCOME")
# Out:
# SALARY
# 2600      2600
# 2600      2600
# 4400      4400
# 13000    13000
# 6000      6000
# 6500      6500
# 10000    10000
# 12008    12008
# 8300      8300
# 24000    24000
# 17000    17000
# 17000    17000
# 9000      9000
# 6000      6000
# 4800      4800
# 4800      4800
# 4200      4200
# 12008    12008
# 9000      9000
# 8200      8200
# 7700      7700
# 7800      7800
# 6900      6900
# 11000    11000
# 3100      3100
# 2900      2900
# 2800      2800
# 2600      2600
# 2500      2500
# 8000      8000
# 8200      8200
# 7900      7900
# 6500      6500
# 5800      5800
# 3200      3200
# 2700      2700
# 2400      2400
# 2200      2200
# 3300      3300
# 2800      2800
# 2500      2500
# 2100      2100
# 3300      3300
# 2900      2900
# 2400      2400
# 2200      2200
# 3600      3600
# 3200      3200
# 2700      2700
# 2500      2500
# Name: SALARY, dtype: int64

# %%
#8. Create the rows and add it with original dataset
# Values of variable, instruction about the variable

row_insert = pd.Series(['1000000000','ti','ta','kjjbk','0117869','12-m-22','hg','hj','tt','ninta','titi'], index = ['EMPLOYEE_ID','FIRST_NAME','LAST_NAME','EMAIL','PHONE_NUMBER','	HIRE_DATE','JOB_ID','SALARY','COMMISSION_PCT','MANAGER_ID','DEPARTMENT_ID'])

# %%
#9 call the row
dataset.iloc[0]
dataset.iloc[1:5]
dataset.iloc[1:4]
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10
# 3    MK_MAN   13000             -         100             20

# %%
#10. Rename the columns
dataset.rename(columns = {'SALARY' : 'CASH'}).head(5)
# Out:
#         EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# SALARY
# 2600            198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 2600            199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 4400            200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 13000           201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 6000            202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#           JOB_ID   CASH COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# SALARY
# 2600    SH_CLERK   2600             -         124             50
# 2600    SH_CLERK   2600             -         124             50
# 4400     AD_ASST   4400             -         101             10
# 13000     MK_MAN  13000             -         100             20
# 6000      MK_REP   6000             -         201             20

# %%
#11 Rename
dataset.rename(columns = {"Admin2":"Admin"}).head(5)
# Out:
#         EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# SALARY
# 2600            198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 2600            199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 4400            200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 13000           201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 6000            202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#           JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# SALARY
# 2600    SH_CLERK    2600             -         124             50
# 2600    SH_CLERK    2600             -         124             50
# 4400     AD_ASST    4400             -         101             10
# 13000     MK_MAN   13000             -         100             20
# 6000      MK_REP    6000             -         201             20

# %%
# Find the minimum and maximum, sum, count
dataset.min()
dataset.max()
dataset.sum()
dataset.count()
# Out:
# EMPLOYEE_ID       50
# FIRST_NAME        50
# LAST_NAME         50
# EMAIL             50
# PHONE_NUMBER      50
# HIRE_DATE         50
# JOB_ID            50
# SALARY            50
# COMMISSION_PCT    50
# MANAGER_ID        50
# DEPARTMENT_ID     50
# dtype: int64

# %%
#12 delete colum
dataset.drop(dataset.columns[2], axis = 1) #delete column at index 1
# Out:
#         EMPLOYEE_ID   FIRST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# SALARY
# 2600            198       Donald  DOCONNEL  650.507.9833  21-JUN-07
# 2600            199      Douglas    DGRANT  650.507.9844  13-JAN-08
# 4400            200     Jennifer   JWHALEN  515.123.4444  17-SEP-03
# 13000           201      Michael  MHARTSTE  515.123.5555  17-FEB-04
# 6000            202          Pat      PFAY  603.123.6666  17-AUG-05
# 6500            203        Susan   SMAVRIS  515.123.7777  07-JUN-02
# 10000           204      Hermann     HBAER  515.123.8888  07-JUN-02
# 12008           205      Shelley  SHIGGINS  515.123.8080  07-JUN-02
# 8300            206      William    WGIETZ  515.123.8181  07-JUN-02
# 24000           100       Steven     SKING  515.123.4567  17-JUN-03
# 17000           101        Neena  NKOCHHAR  515.123.4568  21-SEP-05
# 17000           102          Lex   LDEHAAN  515.123.4569  13-JAN-01
# 9000            103    Alexander   AHUNOLD  590.423.4567  03-JAN-06
# ...

# %%
# unique value
dataset['SALARY'].unique()
# Out:
# array([ 2600,  4400, 13000,  6000,  6500, 10000, 12008,  8300, 24000,
#        17000,  9000,  4800,  4200,  8200,  7700,  7800,  6900, 11000,
#         3100,  2900,  2800,  2500,  8000,  7900,  5800,  3200,  2700,
#         2400,  2200,  3300,  2100,  3600])
